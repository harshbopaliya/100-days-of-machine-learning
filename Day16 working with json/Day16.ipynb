# %%
import pandas as pd

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://v6.exchangerate-api.com/v6/c46bf38b97bbe0cdcb645af4/latest/USD')
# Out:
#       result                          documentation  \
# USD  success  https://www.exchangerate-api.com/docs
# AED  success  https://www.exchangerate-api.com/docs
# AFN  success  https://www.exchangerate-api.com/docs
# ALL  success  https://www.exchangerate-api.com/docs
# AMD  success  https://www.exchangerate-api.com/docs
# ..       ...                                    ...
# XPF  success  https://www.exchangerate-api.com/docs
# YER  success  https://www.exchangerate-api.com/docs
# ZAR  success  https://www.exchangerate-api.com/docs
# ZMW  success  https://www.exchangerate-api.com/docs
# ZWL  success  https://www.exchangerate-api.com/docs
#
#                                terms_of_use  time_last_update_unix  \
# USD  https://www.exchangerate-api.com/terms             1724630401
# AED  https://www.exchangerate-api.com/terms             1724630401
# AFN  https://www.exchangerate-api.com/terms             1724630401
# ...

# %% [markdown]
# # working with sql

# %%
from sqlalchemy import create_engine
import pandas as pd
import mysql.connector

# %%
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='',
    database='world'
)

# %%
engine = create_engine("mysql+mysqlconnector://root:@localhost/world")

# %%
df = pd.read_sql_query("SELECT * FROM city where CountryCode LIKE 'USA' ", engine)

# %%
conn.close()

# %%
df
# Out:
#        ID          Name CountryCode        District  Population
# 0    3793      New York         USA        New York     8008278
# 1    3794   Los Angeles         USA      California     3694820
# 2    3795       Chicago         USA        Illinois     2896016
# 3    3796       Houston         USA           Texas     1953631
# 4    3797  Philadelphia         USA    Pennsylvania     1517550
# ..    ...           ...         ...             ...         ...
# 269  4062       Kenosha         USA       Wisconsin       89447
# 270  4063         Elgin         USA        Illinois       89408
# 271  4064        Odessa         USA           Texas       89293
# 272  4065        Carson         USA      California       89089
# 273  4066    Charleston         USA  South Carolina       89063
#
# [274 rows x 5 columns]

# %%
df2= pd.read_sql_query("SELECT * FROM country where LifeExpectancy>60", engine)
df2
# Out:
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 162  VIR  Virgin Islands, U.S.  North America        Caribbean        347.0
# 163  VNM               Vietnam           Asia   Southeast Asia     331689.0
# 164  VUT               Vanuatu        Oceania        Melanesia      12189.0
# 165  WSM                 Samoa        Oceania        Polynesia       2831.0
# 166  YUG            Yugoslavia         Europe  Southern Europe     102173.0
#
# ...

# %%
df3 = pd.read_sql_query("SELECT * FROM countrylanguage where IsOfficial like 'F' ", engine)
df3
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW     English          F         9.5
# 1           ABW  Papiamento          F        76.7
# 2           ABW     Spanish          F         7.4
# 3           AFG     Balochi          F         0.9
# 4           AFG  Turkmenian          F         1.9
# ..          ...         ...        ...         ...
# 741         ZMB      Nyanja          F         7.8
# 742         ZMB      Tongan          F        11.0
# 743         ZWE     Ndebele          F        16.2
# 744         ZWE      Nyanja          F         2.2
# 745         ZWE       Shona          F        72.1
#
# [746 rows x 4 columns]
